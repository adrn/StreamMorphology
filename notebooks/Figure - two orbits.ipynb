# %%
from __future__ import division, print_function

# Third-party
import astropy.units as u
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# Custom
import gary.dynamics as gd
import gary.integrate as gi
import gary.io as io
import gary.potential as gp
from gary.units import galactic

# project
from streammorphology.freqmap import read_allfreqs
from streammorphology.potential import potential_registry
potential = potential_registry['triaxial-NFW']

# %%
# slow_fast_w0 = np.array([[-6.307612066581242, 18.267854330751966, -12.879880916111173, -0.11721795085114858, -0.10083940862243289, -0.08575822919558719], 
#                          [-5.969812074862913, 18.238225582935204, -12.734525319548624, -0.11777839740390844, -0.09996568567305107, -0.0878360630166049]])

# %%
# t,w = potential.integrate_orbit(slow_fast_w0, dt=0.5, nsteps=400000,
#                                 Integrator=gi.DOPRI853Integrator)

# %%
# np.save("/Users/adrian/projects/gary/test-data/naff/t.npy", t)
# np.save("/Users/adrian/projects/gary/test-data/naff/w.npy", w)

# %%
t = np.load("/Users/adrian/projects/gary/test-data/naff/t.npy")
w = np.load("/Users/adrian/projects/gary/test-data/naff/w.npy")

# %%
np.savetxt("/Users/adrian/projects/gary/test-data/naff/regular.dat", np.vstack((t, w[:,0].T)).T)
np.savetxt("/Users/adrian/projects/gary/test-data/naff/chaotic.dat", np.vstack((t, w[:,1].T)).T)

# %%
fig,axes = plt.subplots(1,2,figsize=(10,5),sharex=True,sharey=True)

for i in range(2):
    axes[i].plot(w[:100000,i,0], w[:100000,i,1], marker='.', linestyle='none', alpha=0.025)
    
fig.tight_layout()

# %%
fig,axes = plt.subplots(1,2,figsize=(10,5),sharex=True,sharey=True)

for i in range(2):
    axes[i].plot(w[-100000:,i,0], w[-100000:,i,1], marker='.', linestyle='none', alpha=0.025)
    
fig.tight_layout()

# %% [markdown]
# ## Frequency Diffusion

# %%
max_ix = 200000
dwindow = 25000
edges = range(0,max_ix+dwindow,dwindow)
print(edges)
print(len(edges))

for ed in edges:
    print(0+ed, max_ix+ed)
# Out:
# [0, 25000, 50000, 75000, 100000, 125000, 150000, 175000, 200000]
# 9
# 0 200000
# 25000 225000
# 50000 250000
# 75000 275000
# 100000 300000
# 125000 325000
# 150000 350000
# 175000 375000
# 200000 400000

# %%
slow_freqs = list()
for i in edges:
    freqs,d,ixes,is_tube = gd.naff.orbit_to_freqs(t[0+i:max_ix+i+1], w[0+i:max_ix+i+1,0], silently_fail=False)
    slow_freqs.append(freqs.tolist())

# %%
fast_freqs = list()
for i in edges:
    freqs,d,ixes,is_tube = gd.naff.orbit_to_freqs(t[0+i:max_ix+i], w[0+i:max_ix+i,1], silently_fail=False)
    fast_freqs.append(freqs.tolist())

# %%
# s_freqs1,d_s1,ixes_s1,is_tube = gd.naff.orbit_to_freqs(t[:len(t)//2+1], w[:len(t)//2+1,0], silently_fail=False)
# s_freqs2,d_s2,ixes_s2,is_tube = gd.naff.orbit_to_freqs(t[len(t)//2:], w[len(t)//2:,0], silently_fail=False)

# f_freqs1,d_f1,ixes_f1,is_tube = gd.naff.orbit_to_freqs(t[:len(t)//2+1], w[:len(t)//2+1,1], silently_fail=False)
# f_freqs2,d_f2,ixes_f2,is_tube = gd.naff.orbit_to_freqs(t[len(t)//2:], w[len(t)//2:,1], silently_fail=False)

# %%
slow_freqs = np.abs(slow_freqs)
fast_freqs = np.abs(fast_freqs)

# %%
plt.figure()
plt.plot(slow_freqs[:,:]);

plt.figure()
plt.plot(fast_freqs[:,:]);

# %%
fig,axes = plt.subplots(1,2,figsize=(12,6), sharex=True, sharey=True)

# axes[0].plot(slow_freqs[:,1]/slow_freqs[:,0], slow_freqs[:,2]/slow_freqs[:,0], 
#              marker='.', linestyle='-')

# axes[1].plot(fast_freqs[:,1]/fast_freqs[:,0], fast_freqs[:,2]/fast_freqs[:,0], 
#              marker='.', linestyle='-')

axes[0].plot(slow_freqs[:,1]*1000, slow_freqs[:,2]*1000, 
             marker='.', linestyle='-')

axes[1].plot(fast_freqs[:,1]*1000, fast_freqs[:,2]*1000, 
             marker='.', linestyle='-')

axes[0].set_xlabel(r"$\Omega_2 \, [{\rm Gyr}^{-1}]$")
axes[0].set_ylabel(r"$\Omega_3 \, [{\rm Gyr}^{-1}]$")
axes[1].set_xlabel(r"$\Omega_2 \, [{\rm Gyr}^{-1}]$")

# axes[0].set_xlim(0.6,0.65)
# axes[0].set_ylim(0.65,0.7)

fig.tight_layout()

# %% [markdown]
# ## Lyapunov exponent

# %% [markdown]
# Get maximum period to convert time into number of orbital periods

# %%
slow_T_max = 2*np.pi / slow_freqs[0].min()
fast_T_max = 2*np.pi / fast_freqs[0].min()

# %%
def F_max(t,w):
    x,y,z,px,py,pz = w.T
    term1 = np.array([px, py, pz]).T
    term2 = potential.acceleration(w[...,:3])
    return np.hstack((term1,term2))

integrator = gi.DOPRI853Integrator(F_max)

# %%
sl_LEs, sl_lyap_ts, sl_lyap_ws = gd.lyapunov_max(slow_fast_w0[0], integrator, dt=2., nsteps=300000)
fa_LEs, fa_lyap_ts, fa_lyap_ws = gd.lyapunov_max(slow_fast_w0[1], integrator, dt=2., nsteps=300000)

# %%
sl_ix = sl_LEs[-1].argmax()
fa_ix = fa_LEs[-1].argmax()

# %%
fig,axes = plt.subplots(2, 1, figsize=(8,8), sharex=True, sharey=True)

axes[0].loglog(sl_lyap_ts[::10][1:-1] / slow_T_max, sl_LEs[:,sl_ix], 
               linestyle='-', c='k', marker=None)

axes[1].loglog(fa_lyap_ts[::10][1:-1] / fast_T_max, fa_LEs[:,sl_ix], 
               linestyle='-', c='k', marker=None)

tt = np.linspace(1,1E3,100)
axes[0].loglog(tt, 0.005/tt**0.9, linestyle='--', c='#0868ac', marker=None)
axes[1].loglog(tt, 0.005/tt**0.9, linestyle='--', c='#0868ac', marker=None)
# axes[0].loglog(tt, 0.003/tt, linestyle='--', c='#0868ac', marker=None)
# axes[1].loglog(tt, 0.003/tt, linestyle='--', c='#0868ac', marker=None)

axes[0].set_xlim(1,1000)
axes[0].set_ylim(1E-5,1E-2)

axes[1].set_xlabel(r"Number of orbital periods, $N_{T_{\rm max}}$")
axes[0].set_ylabel(r"$l_N$", rotation='horizontal')
axes[1].set_ylabel(r"$l_N$", rotation='horizontal')

fig.tight_layout()
fig.savefig("/Users/adrian/papers/papers/stream-morphology/figures/lyap-orbits.pdf")
